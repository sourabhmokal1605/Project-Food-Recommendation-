# %%
import matplotlib as plt
import pandas as pd

# %%
df= pd.read_csv('indian_food.csv')

# %%
df.head(20)
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# 12       Nankhatai  Refined flour, besan, ghee, powdered sugar, yo...
# 13           Petha  Firm white pumpkin, sugar, kitchen lime, alum ...
# 14          Phirni                                  Rice, sugar, nuts
# 15           Rabri                Condensed milk, sugar, spices, nuts
# 16          Sheera                         Semolina, ghee, nuts, milk
# 17         Singori                           Khoa, coconut, molu leaf
# 18     Sohan halwa                       Corn flour, ghee, dry fruits
# 19     Sohan papdi            Gram flour, ghee, sugar, milk, cardamom
#
#           diet  cook_time_IN_MIN flavor_profile   course  \
# 0   vegetarian              25.0          sweet  dessert
# 1   vegetarian              30.0          sweet  dessert
# 2   vegetarian              60.0          sweet  dessert
# 3   vegetarian              30.0          sweet  dessert
# 4   vegetarian              40.0          sweet  dessert
# 5   vegetarian              50.0          sweet  dessert
# 6   vegetarian              50.0          sweet  dessert
# 7   vegetarian              20.0          sweet  dessert
# 8   vegetarian              30.0          sweet  dessert
# 9   vegetarian              40.0          sweet  dessert
# 10  vegetarian              40.0          sweet  dessert
# 11  vegetarian               5.0          sweet  dessert
# 12  vegetarian              30.0          sweet  dessert
# 13  vegetarian              30.0          sweet  dessert
# 14  vegetarian              20.0          sweet  dessert
# 15  vegetarian              45.0          sweet  dessert
# 16  vegetarian              25.0          sweet  dessert
# 17  vegetarian              20.0          sweet  dessert
# 18  vegetarian              60.0          sweet  dessert
# 19  vegetarian              60.0          sweet  dessert
#
#                         state region price_in_INR
# 0                 West Bengal   East       600/kg
# 1                   Rajasthan   West       400/kg
# 2                      Punjab  North           90
# 3                   Rajasthan   West          450
# 4                 West Bengal   East       200/kg
# 5                 West Bengal   East       100/kg
# 6               Uttar Pradesh  North       200/kg
# 7                      Gujrat   west       800/kg
# 8                 West Bengal   East       400/kg
# 9                 Maharashtra   west           50
# 10  depends on type you take.    NaN       300/kg
# 11                     Punjab  North           15
# 12                     Gujrat   west       300/kg
# 13              Uttar Pradesh  North       350/kg
# 14                     Odisha   East       350/kg
# 15              Uttar Pradesh  North       200/kg
# 16                Maharashtra   West       150/kg
# 17                Uttarakhand  North       100/kg
# 18              Uttar Pradesh  North       150/kg
# 19                Maharashtra   West       150/kg

# %%
print(df[['name','course','state']])
# Out:
#                name      course        state
# 0        Balu shahi     dessert  West Bengal
# 1            Boondi     dessert    Rajasthan
# 2    Gajar ka halwa     dessert       Punjab
# 3            Ghevar     dessert    Rajasthan
# 4       Gulab jamun     dessert  West Bengal
# ..              ...         ...          ...
# 261    mutton curry  maincourse  Maharashtra
# 262     chicken dry  maincourse  maharashtra
# 263   chicken curry  maincourse  Maharashtra
# 264     Kanda bhaji       snack  maharashtra
# 265       Misal pav       snack  Maharashtra
#
# [266 rows x 3 columns]

# %%
df.course.value_counts()
# Out:
# maincourse    118
# dessert        79
# snack          40
# starter         2
# Snack           1
# Name: course, dtype: int64

# %%
df.course.value_counts()
# Out:
# maincourse    118
# dessert        79
# snack          40
# starter         2
# Snack           1
# Name: course, dtype: int64

# %%
df.course.value_counts(normalize=True)
# Out:
# maincourse    0.491667
# dessert       0.329167
# snack         0.166667
# starter       0.008333
# Snack         0.004167
# Name: course, dtype: float64

# %%
df.course.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
df[df['course']=='snack']
# Out:
#                   name                                        ingredients  \
# 88                Poha  Beaten rice flakes, potato, curry leaves, gree...
# 89                Fara  Chana dal, whole wheat flour, arhar dal, white...
# 90             Kachori  Moong dal, rava, garam masala, dough, fennel s...
# 109          Pani puri      Kala chana, mashed potato, boondi, sev, lemon
# 111              Papad       Urad dal, sev, lemon juice, chopped tomatoes
# 117             Samosa  Potatoes, green peas, garam masala, ginger, dough
# 124               Attu  Whole wheat flour, arhar dal, ginger, kala jee...
# 128               Dosa  Chana dal, urad dal, whole urad dal, blend ric...
# 129           Idiappam              Rice flour, hot water, grated coconut
# 130               Idli  Split urad dal, urad dal, idli rice, thick poh...
# 131              Kanji     Carrot, yellow mustard, red chilli, black salt
# 144        Masala Dosa  Chana dal, urad dal, potatoes, idli rice, thic...
# 147            Papadum               Lentils, black pepper, vegetable oil
# 151          Pesarattu                      Green moong beans, rice flour
# 161            Uttapam    Chana dal, urad dal, thick poha, tomato, butter
# 162               Vada  Urad dal, ginger, curry leaves, green chilies,...
# 164               Upma   Chana dal, urad dal, ginger, curry leaves, sugar
# 173            Chakali  Rice flour, sesame, plain flour, turmeric, red...
# 174             Chevdo       Citric acid, fry, raisins, sugar, chana daal
# 175          Chorafali  Urad dal, bengal gram flour, dried mango, baki...
# 178      Kutchi dabeli         Pav, aloo, peanut, pomegranate, star anise
# 179          Dahi vada  Urad dal, bhuna chana, garam masala, dates, ta...
# 181             Dhokla         Rava, coconut, gram flour, mustard, sesame
# 186             Handwo  Bottle gourd, chana dal, cabbage, urad dal, to...
# 191            Khakhra      Whole wheat flour, low fat, bengal gram flour
# 192            Khandvi  Green chili paste, white sesame seeds, gram fl...
# 193        Kombdi vade  Rice flour, urad dal, wheat flour, gram flour,...
# 198            Muthiya  Bottle gourd, whole wheat flour, rava, sesame ...
# 199              Patra  Arbi ke patte, sesame seeds, gur, bengal gram ...
# 202  Sabudana Khichadi  Raw peanuts, sabudana, lemon, avocado oil, cur...
# 205          Namakpara  Wheat flour, baking soda, all purpose flour, b...
# 207            Surnoli  Rice flakes, yogurt, raw rice, jaggery, grated...
# 212      Lilva Kachori  Green garlic chutney, fresh green peas, ginger...
# 213         Mag Dhokli      Moong beans, jaggery, red chillies, oil, salt
# 214             Khichu  Rice flour, sesame seeds, baking soda, peanut oil
# 215             Thepla  Chickpea flour, methi leaves, jowar flour, whe...
# 217             Khaman  Yogurt, fresh coconut, sesame seeds, semolina,...
# 255          Vada Pav   boiled mashed potatoes, gram flour batter, oil...
# 264        Kanda bhaji                       onion,chana flour,masala,oil
# 265          Misal pav          curry,onion,chiwada,tomato,pav,oil,potato
#
#            diet  cook_time_IN_MIN flavor_profile course           state  \
# 88   vegetarian              30.0          spicy  snack     Maharashtra
# 89   vegetarian              60.0          spicy  snack    Chhattisgarh
# 90   vegetarian              60.0          spicy  snack   Uttar Pradesh
# 109  vegetarian               2.0          spicy  snack   Uttar Pradesh
# 111  vegetarian               5.0          spicy  snack      Tamil Nadu
# 117  vegetarian              30.0          spicy  snack          Punjab
# 124  vegetarian              25.0          spicy  snack  Andhra Pradesh
# 128  vegetarian              90.0          spicy  snack       Karnataka
# 129  vegetarian              30.0          spicy  snack      Tamil Nadu
# 130  vegetarian              90.0          spicy  snack      Tamil Nadu
# 131  vegetarian              45.0            NaN  snack          Kerala
# 144  vegetarian              90.0          spicy  snack      Tamil Nadu
# 147  vegetarian               5.0          spicy  snack          Kerala
# 151  vegetarian              20.0          spicy  snack  Andhra Pradesh
# 161  vegetarian              20.0          spicy  snack      Tamil Nadu
# 162  vegetarian              20.0          spicy  snack       Karnataka
# 164  vegetarian              20.0          spicy  snack       Karnataka
# 173  vegetarian              40.0          spicy  snack     Maharashtra
# 174  vegetarian              30.0          spicy  snack         Gujarat
# 175  vegetarian              15.0          spicy  snack         Gujarat
# 178  vegetarian              10.0          spicy  snack         Gujarat
# 179  vegetarian              30.0          sweet  snack     Maharashtra
# 181  vegetarian              20.0          spicy  snack         Gujarat
# 186  vegetarian              30.0          spicy  snack         Gujarat
# 191  vegetarian              40.0          spicy  snack         Gujarat
# 192  vegetarian              45.0          spicy  snack         Gujarat
# 193  vegetarian              25.0          spicy  snack     Maharashtra
# 198  vegetarian              30.0         bitter  snack         Gujarat
# 199  vegetarian              40.0          spicy  snack         Gujarat
# 202  vegetarian              30.0          spicy  snack     Maharashtra
# 205  vegetarian              35.0          spicy  snack         Gujarat
# 207  vegetarian              10.0          spicy  snack     Maharashtra
# 212  vegetarian               6.0          spicy  snack         Gujarat
# 213  vegetarian              -1.0          spicy  snack         Gujarat
# 214  vegetarian              10.0          spicy  snack         Gujarat
# 215  vegetarian              30.0          spicy  snack         Gujarat
# 217  vegetarian              20.0          spicy  snack         Gujarat
# 255  vegetarian               4.0          spicy  snack     Maharashtra
# 264         NaN               5.0          spicy  snack     maharashtra
# 265         NaN              20.0          spicy  snack     Maharashtra
#
#       region price_in_INR
# 88      West          NaN
# 89   Central          NaN
# 90     North          NaN
# 109    North          NaN
# 111    South          NaN
# 117    North          NaN
# 124    South          NaN
# 128    South          NaN
# 129    South          NaN
# 130    South          NaN
# 131    South          NaN
# 144    South          NaN
# 147    South          NaN
# 151    South          NaN
# 161    South          NaN
# 162    South          NaN
# 164    south          NaN
# 173     West          NaN
# 174     West          NaN
# 175     West          NaN
# 178     West          NaN
# 179     West          NaN
# 181     West          NaN
# 186     West          NaN
# 191     West          NaN
# 192     West          NaN
# 193     West          NaN
# 198     West          NaN
# 199     West          NaN
# 202     West          NaN
# 205     West          NaN
# 207     West          NaN
# 212     West          NaN
# 213     West          NaN
# 214     West          NaN
# 215     West          NaN
# 217     West          NaN
# 255     west           15
# 264     west           20
# 265     West           40

# %%
df[df['name']=='chicken dry']
# Out:
#             name                                        ingredients  \
# 262  chicken dry  chicken,masala,turmeric,onion,tomato,oil,spice...
#
#                diet  cook_time_IN_MIN flavor_profile      course        state  \
# 262  non vegetarian              60.0          spicy  maincourse  maharashtra
#
#     region price_in_INR
# 262   west          200

# %%
a=df[df['name']=='chicken dry']['course']

# %%
a
# Out:
# 262    maincourse
# Name: course, dtype: object

# %%
#a.rank()
#df.loc[b,'Genre']

b=a.to_string(index=False)
c=b.replace(" ", "")

# %%
c
# Out:
# 'maincourse'

# %%
x=[]
x.append(c)

# %%
x
# Out:
# ['maincourse']

# %%
y=[]

# %%
for i in df['course']:
    if i==x[0]:
        y.append(df[df['course']==i]['name'])

# %%
y
# Out:
# [46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object,
#  46     Obbattu holige
#  64         Maach Jhol
#  67              Galho
#  68          Aloo gobi
#  69         Aloo tikki
#              ...
#  259        Prawns dry
#  260        mutton dry
#  261      mutton curry
#  262       chicken dry
#  263     chicken curry
#  Name: name, Length: 118, dtype: object]

# %%
z=y[0].to_string(index=False)
q=z.replace(" ", "")

# %%
q
# Out:
# 'Obbattuholige\nMaachJhol\nGalho\nAloogobi\nAlootikki\nAloomatar\nAloomethi\nAlooshimlamirch\nBhatura\nBhindimasala\nBiryani\nButterchicken\nChanamasala\nChapati\nChickenrazala\nChickenTikkamasala\nCholebhature\nDaalbaatichurma\nDaalpuri\nDalmakhani\nDaltadka\nDumaloo\nKadaipaneer\nKadhipakoda\nKarelabharta\nKhichdi\nKofta\nLaukikekofte\nLaukikisubji\nLittichokha\nMakkidirotisarsondasaag\nMisiroti\nMushroomdopyaza\nMushroommatar\nNaan\nNavrattankorma\nPalakpaneer\nPaneerbuttermasala\nPaneertikkamasala\nParatha\nPattor\nPindichana\nRajmachaval\nSattukiroti\nShahipaneer\nVegetablejalfrezi\nTandooriChicken\nAvial\nBisibelebath\nCurrivepillaisadam\nKaarakozhambu\nKeeraikootu\nKeeraimasiyal\nKeeraisadam\nKeeraiporiyal\nKootu\nKoskootu\nKoshambri\nKothamalisadam\nKuzhakkattai\nKuzhambu\nPachadi\nPaniyaram\nParavannam\nParuppusadam\nPoriyal\nPulisadam\nRasam\nPuttu\nSambar\nSandige\nSevai\nThayirsadam\nTheeyal\nChickenVaruval\nAmti\nZunka\nKolimJawla\nSaath\nBajrinorotlo\nBhakri\nBombilfry\nCoprapaak\nDaalDhokli\nDalithoy\nGattacurry\nJeeraAloo\nKerinoras\nLaapsi\nKoshimbir\nMethinaGota\nPavBhaji\nPuriBhaji\nSevkhamani\nSevtameta\nThalipeeth\nUndhiyu\nVegKolhapuri\nVindaloo\nTuriyaPatraVatanasabji\nKhar\nLuchi\nAluPitika\nMasortenga\nBengenaPitika\nBilahiMaas\nBlackrice\nMishtiChholarDal\nPaniPitha\nPrawnmalaicurry\nShukto\nPuranPoli\nPapletfry\nPrawnsdry\nmuttondry\nmuttoncurry\nchickendry\nchickencurry'

# %%
#y[0]
#x=y[0].split(" ")
#sub_df.iloc[0]['A']
answer=q.split("\n")
answer
# Out:
# ['Obbattuholige',
#  'MaachJhol',
#  'Galho',
#  'Aloogobi',
#  'Alootikki',
#  'Aloomatar',
#  'Aloomethi',
#  'Alooshimlamirch',
#  'Bhatura',
#  'Bhindimasala',
#  'Biryani',
#  'Butterchicken',
#  'Chanamasala',
#  'Chapati',
#  'Chickenrazala',
#  'ChickenTikkamasala',
#  'Cholebhature',
#  'Daalbaatichurma',
#  'Daalpuri',
#  'Dalmakhani',
#  'Daltadka',
#  'Dumaloo',
#  'Kadaipaneer',
#  'Kadhipakoda',
#  'Karelabharta',
#  'Khichdi',
#  'Kofta',
#  'Laukikekofte',
#  'Laukikisubji',
#  'Littichokha',
#  'Makkidirotisarsondasaag',
#  'Misiroti',
#  'Mushroomdopyaza',
#  'Mushroommatar',
#  'Naan',
#  'Navrattankorma',
#  'Palakpaneer',
#  'Paneerbuttermasala',
#  'Paneertikkamasala',
#  'Paratha',
#  'Pattor',
#  'Pindichana',
#  'Rajmachaval',
#  'Sattukiroti',
#  'Shahipaneer',
#  'Vegetablejalfrezi',
#  'TandooriChicken',
#  'Avial',
#  'Bisibelebath',
#  'Currivepillaisadam',
#  'Kaarakozhambu',
#  'Keeraikootu',
#  'Keeraimasiyal',
#  'Keeraisadam',
#  'Keeraiporiyal',
#  'Kootu',
#  'Koskootu',
#  'Koshambri',
#  'Kothamalisadam',
#  'Kuzhakkattai',
#  'Kuzhambu',
#  'Pachadi',
#  'Paniyaram',
#  'Paravannam',
#  'Paruppusadam',
#  'Poriyal',
#  'Pulisadam',
#  'Rasam',
#  'Puttu',
#  'Sambar',
#  'Sandige',
#  'Sevai',
#  'Thayirsadam',
#  'Theeyal',
#  'ChickenVaruval',
#  'Amti',
#  'Zunka',
#  'KolimJawla',
#  'Saath',
#  'Bajrinorotlo',
#  'Bhakri',
#  'Bombilfry',
#  'Coprapaak',
#  'DaalDhokli',
#  'Dalithoy',
#  'Gattacurry',
#  'JeeraAloo',
#  'Kerinoras',
#  'Laapsi',
#  'Koshimbir',
#  'MethinaGota',
#  'PavBhaji',
#  'PuriBhaji',
#  'Sevkhamani',
#  'Sevtameta',
#  'Thalipeeth',
#  'Undhiyu',
#  'VegKolhapuri',
#  'Vindaloo',
#  'TuriyaPatraVatanasabji',
#  'Khar',
#  'Luchi',
#  'AluPitika',
#  'Masortenga',
#  'BengenaPitika',
#  'BilahiMaas',
#  'Blackrice',
#  'MishtiChholarDal',
#  'PaniPitha',
#  'Prawnmalaicurry',
#  'Shukto',
#  'PuranPoli',
#  'Papletfry',
#  'Prawnsdry',
#  'muttondry',
#  'muttoncurry',
#  'chickendry',
#  'chickencurry']

# %%
sort=df[df['course']==x[0]]

# %%
sort.sort_values(by=['price_in_INR'], ascending=True).head(10)
# Out:
#                   name                                        ingredients  \
# 249             Shukto  Green beans, bitter gourd, ridge gourd, banana...
# 257         Puran Poli             chana dal, ghee,flour,jaggery,turmeric
# 262        chicken dry  chicken,masala,turmeric,onion,tomato,oil,spice...
# 263      chicken curry  chicken,masala,turmeric,onion,tomato,oil,spice...
# 46      Obbattu holige  Maida flour, turmeric, coconut, chickpeas, jag...
# 247  Prawn malai curry      Coconut milk, prawns, garlic, turmeric, sugar
# 258         Paplet fry               Pomphret, masala,turmeric,garlic,oil
# 259         Prawns dry     prawns,masala,turmeric,onion,garlic,oil,spices
# 260         mutton dry  mutton,masala,turmeric,onion,tomato,oil,spices...
# 261       mutton curry  mutton,masala,turmeric,onion,tomato,oil,spices...
#
#                diet  cook_time_IN_MIN flavor_profile      course        state  \
# 249      vegetarian              20.0          spicy  maincourse  West Bengal
# 257      vegetarian              10.0          sweet  maincourse  maharashtra
# 262  non vegetarian              60.0          spicy  maincourse  maharashtra
# 263  non vegetarian              60.0          spicy  maincourse  Maharashtra
# 46       vegetarian              60.0          sweet  maincourse    Karnataka
# 247  non vegetarian              50.0          spicy  maincourse  West Bengal
# 258  Non vegetarian              20.0          spicy  maincourse  maharashtra
# 259  non vegetarian              20.0          spicy  maincourse  maharashtra
# 260  Non vegetarian              90.0          spicy  maincourse  Maharashtra
# 261  non vegetarian              90.0          spicy  maincourse  Maharashtra
#
#     region price_in_INR
# 249   East          100
# 257   west          150
# 262   west          200
# 263   west          200
# 46   South       200/kg
# 247   East          250
# 258   west          250
# 259   west          250
# 260   west          300
# 261   west          300

# %%
dish_name="Prawns dry"

# %%
import matplotlib as plt
import pandas as pd

df= pd.read_csv('indian_food.csv')
a=df[df['name']==dish_name]['course']

b=a.to_string(index=False)
c=b.replace(" ", "")
x=[]
x.append(c)
y=[]
for i in df['course']:
    if i==x[0]:
        y.append(df[df['course']==i]['name'])
z=y[0].to_string(index=False)
q=z.replace(" ", "")
answer=q.split("\n")

# %%
answerimport matplotlib as plt
import pandas as pd

df= pd.read_csv('indian_food.csv')
a=df[df['name']==dish_name]['course']

b=a.to_string(index=False)
c=b.replace(" ", "")
x=[]
x.append(c)
y=[]
for i in df['course']:
    if i==x[0]:
        y.append(df[df['course']==i]['name'])
z=y[0].to_string(index=False)
q=z.replace(" ", "")
answer=q.split("\n")
# Out:
# ['Obbattuholige',
#  'MaachJhol',
#  'Galho',
#  'Aloogobi',
#  'Alootikki',
#  'Aloomatar',
#  'Aloomethi',
#  'Alooshimlamirch',
#  'Bhatura',
#  'Bhindimasala',
#  'Biryani',
#  'Butterchicken',
#  'Chanamasala',
#  'Chapati',
#  'Chickenrazala',
#  'ChickenTikkamasala',
#  'Cholebhature',
#  'Daalbaatichurma',
#  'Daalpuri',
#  'Dalmakhani',
#  'Daltadka',
#  'Dumaloo',
#  'Kadaipaneer',
#  'Kadhipakoda',
#  'Karelabharta',
#  'Khichdi',
#  'Kofta',
#  'Laukikekofte',
#  'Laukikisubji',
#  'Littichokha',
#  'Makkidirotisarsondasaag',
#  'Misiroti',
#  'Mushroomdopyaza',
#  'Mushroommatar',
#  'Naan',
#  'Navrattankorma',
#  'Palakpaneer',
#  'Paneerbuttermasala',
#  'Paneertikkamasala',
#  'Paratha',
#  'Pattor',
#  'Pindichana',
#  'Rajmachaval',
#  'Sattukiroti',
#  'Shahipaneer',
#  'Vegetablejalfrezi',
#  'TandooriChicken',
#  'Avial',
#  'Bisibelebath',
#  'Currivepillaisadam',
#  'Kaarakozhambu',
#  'Keeraikootu',
#  'Keeraimasiyal',
#  'Keeraisadam',
#  'Keeraiporiyal',
#  'Kootu',
#  'Koskootu',
#  'Koshambri',
#  'Kothamalisadam',
#  'Kuzhakkattai',
#  'Kuzhambu',
#  'Pachadi',
#  'Paniyaram',
#  'Paravannam',
#  'Paruppusadam',
#  'Poriyal',
#  'Pulisadam',
#  'Rasam',
#  'Puttu',
#  'Sambar',
#  'Sandige',
#  'Sevai',
#  'Thayirsadam',
#  'Theeyal',
#  'ChickenVaruval',
#  'Amti',
#  'Zunka',
#  'KolimJawla',
#  'Saath',
#  'Bajrinorotlo',
#  'Bhakri',
#  'Bombilfry',
#  'Coprapaak',
#  'DaalDhokli',
#  'Dalithoy',
#  'Gattacurry',
#  'JeeraAloo',
#  'Kerinoras',
#  'Laapsi',
#  'Koshimbir',
#  'MethinaGota',
#  'PavBhaji',
#  'PuriBhaji',
#  'Sevkhamani',
#  'Sevtameta',
#  'Thalipeeth',
#  'Undhiyu',
#  'VegKolhapuri',
#  'Vindaloo',
#  'TuriyaPatraVatanasabji',
#  'Khar',
#  'Luchi',
#  'AluPitika',
#  'Masortenga',
#  'BengenaPitika',
#  'BilahiMaas',
#  'Blackrice',
#  'MishtiChholarDal',
#  'PaniPitha',
#  'Prawnmalaicurry',
#  'Shukto',
#  'PuranPoli',
#  'Papletfry',
#  'Prawnsdry',
#  'muttondry',
#  'muttoncurry',
#  'chickendry',
#  'chickencurry']
